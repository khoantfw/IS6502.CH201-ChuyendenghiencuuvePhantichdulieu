# %% [markdown]
# # EDA and model results
# Run `python3 run_pipeline.py` first. This notebook reads generated artifacts; analytical decisions remain in `src/hr_recourse`.

# %%
from pathlib import Path
import pandas as pd
ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
tables = ROOT / 'outputs' / 'tables'
display(pd.read_csv(tables / 'data_quality_summary.csv'))
display(pd.read_csv(tables / 'model_comparison.csv'))
display(pd.read_csv(tables / 'final_model_metrics.csv'))

# %%
display(pd.read_csv(tables / 'shap_feature_importance.csv').head(15))
display(pd.read_csv(tables / 'shap_group_importance.csv'))
